# %%
import numpy as np
import pandas as pd
import plotly.express as px
import seaborn as sns

# %%
df = pd.read_csv('2018_sm_global.csv')

# %%
df.head()
# Out:
#               Date_UTC  SML  SMU  SMR  GSM_Bx  GSM_By  GSM_Bz    GSE_Vx  \
# 0  2018-01-01 00:00:00 -187   81 -3.8    0.29   -4.61   -5.16  999999.0
# 1  2018-01-01 00:01:00 -188   84 -3.8    1.54   -6.64   -4.20     368.4
# 2  2018-01-01 00:02:00 -185   83 -3.9    1.41   -6.02   -4.24     368.5
# 3  2018-01-01 00:03:00 -187   85 -3.9    1.29   -5.61   -4.48     373.1
# 4  2018-01-01 00:04:00 -187   83 -4.5    1.27   -5.60   -4.39     371.7
#
#       GSE_Vy     GSM_Vz  CLOCK_ANGLE_GSM   DENSITY      PDYN   EPSILON  \
# 0  999999.00  999999.00            221.8  999999.0  999999.0  999999.0
# 1       6.34     -33.90            237.7      13.5       3.7     276.5
# 2       6.15     -33.85            234.8      13.4       3.7     255.7
# 3       0.67     -32.31            231.4      13.2       3.7     260.3
# 4       0.84     -32.87            231.9      13.1       3.7     252.5
#
#      NEWELL
# 0  999999.0
# 1    7331.6
# 2    7276.7
# 3    7572.4
# 4    7446.5

# %%
df= df.replace([99999.9, 9999.99, 999.99, 999999.0 ,999999.00, '#REF!'], np.nan) #OMNIweb database encodes missing values this way

# %%
from matplotlib.dates import WeekdayLocator

def plot_series(x, y):
    fig, ax = plt.subplots()
    ax.plot_date(x, y, fmt='g--') # x = array of dates, y = array of numbers        

    fig.autofmt_xdate()

    # For tickmarks and ticklabels every fourth week
    ax.xaxis.set_major_locator(WeekdayLocator(byweekday=MO, interval=4))

    # For tickmarks (no ticklabel) every week
    ax.xaxis.set_minor_locator(WeekdayLocator(byweekday=MO))

    # Grid for both major and minor ticks
    plt.grid(True, which='both')
    plt.show()

# %%
x = df.Date_UTC
y = df.SML
plot_series(x, y)
# Out:
# C:\Users\cgree\.conda\envs\keras-gpu\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning:
#
# Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-4f748f2d64cc> in <module>
#       1 x = df.Date_UTC
#       2 y = df.SML
# ----> 3 plot_series(x, y)
#
# <ipython-input-13-8d3439f18705> in plot_series(x, y)
#       5     ax.plot_date(x, y, fmt='g--') # x = array of dates, y = array of numbers
#       6
# ----> 7     fig.autofmt_xdate()
#       8
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

x = df.Date_UTC
y = df.SML

fig, ax = plt.subplots()
ax.plot(x, y)
#ax.set_xlim(-200, 200)
#ax.set_ylim(-1, 1)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-0b1bc89a405a> in <module>
#      10 #ax.set_ylim(-1, 1)
#      11
# ---> 12 plt.show()
#
# ~\.conda\envs\keras-gpu\lib\site-packages\matplotlib\pyplot.py in show(*args, **kw)
#     267     """
#     268     global _show
# --> 269     return _show(*args, **kw)
#     270
#     271
#
# ~\.conda\envs\keras-gpu\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# ~\.conda\envs\keras-gpu\lib\site-packages\ipykernel\pylab\backend_inline.py in _fetch_figure_metadata(fig)
#     175         # the background is transparent
# ...
